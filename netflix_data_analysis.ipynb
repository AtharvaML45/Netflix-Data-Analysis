# %% [markdown]
# <div style="background-color: #0f0f0f; padding: 20px; border-radius: 10px; box-shadow: 5px 5px 10px #888888;">
# <h1 style="color: white; font-size: 30px; font-weight: bold; text-align: center; text-shadow: 2px 2px 4px #000000;">Import Needed Libraries</h1>
# </div>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import plotly.express as px
import matplotlib.pyplot as plt
import plotly.graph_objects as go
from plotly.offline import iplot, plot
from plotly.subplots import make_subplots

colors = ["#8c0404","#f25ed0","#000000","#16A085","#34495E",
           "#21618C ","#512E5F","#45B39D","#AAB7B8 ","#20B2AA",
           "#FF69B4","#00CED1","#FF7F50","#7FFF00","#DA70D6"]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv("/content/drive/MyDrive/netflix1.csv")
df.sample(5)
# Out:
#      show_id     type                         title            director  \
# 7081   s1990  TV Show                          Baby           Not Given
# 6457   s8700    Movie                    Warehoused  Jack Zagha Kababie
# 1284   s1390    Movie                 Friendsgiving         Nicol Paone
# 240    s1915  TV Show  Journey of an African Colony           Not Given
# 8509   s7102  TV Show                          마녀사냥           Not Given
#
#             country date_added  release_year rating   duration  \
# 7081          Italy  9/16/2020          2020  TV-MA  3 Seasons
# 6457         Mexico  11/1/2017          2015  TV-14     92 min
# 1284  United States  1/21/2021          2020      R     95 min
# 240        Pakistan  10/1/2020          2018  TV-MA   1 Season
# 8509    South Korea  2/19/2018          2015  TV-MA   1 Season
#
#                                               listed_in
# 7081   International TV Shows, TV Dramas, Teen TV Shows
# ...

# %% [markdown]
# <div style="background-color: #0f0f0f; padding: 20px; border-radius: 10px; box-shadow: 5px 5px 10px #888888;">
# <h1 style="color: white; font-size: 30px; font-weight: bold; text-align: center; text-shadow: 2px 2px 4px #000000;">Loading Dataset And Get Info</h1>
# </div>

# %%
# Shape of DataSet
print(f"Number of column :{df.shape[1]}\nNumber of rows :{df.shape[0]}")
# Out:
# Number of column :10
# Number of rows :8790

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8790 entries, 0 to 8789
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8790 non-null   object
#  1   type          8790 non-null   object
#  2   title         8790 non-null   object
#  3   director      8790 non-null   object
#  4   country       8790 non-null   object
#  5   date_added    8790 non-null   object
#  6   release_year  8790 non-null   int64
#  7   rating        8790 non-null   object
#  8   duration      8790 non-null   object
#  9   listed_in     8790 non-null   object
# dtypes: int64(1), object(9)
# memory usage: 686.8+ KB

# %%
df.isnull().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# dtype: int64

# %%
df.describe()
# Out:
#        release_year
# count   8790.000000
# mean    2014.183163
# std        8.825466
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %%
df.describe(exclude=np.number)
# Out:
#        show_id   type  title   director        country date_added rating  \
# count     8790   8790   8790       8790           8790       8790   8790
# unique    8790      2   8787       4528             86       1713     14
# top         s1  Movie  9-Feb  Not Given  United States   1/1/2020  TV-MA
# freq         1   6126      2       2588           3240        110   3205
#
#         duration                     listed_in
# count       8790                          8790
# unique       220                           513
# top     1 Season  Dramas, International Movies
# freq        1791                           362

# %%
pd.DataFrame({
    'count':df.shape[0],
    'Nulls':df.isnull().sum(),
    'nulls%':df.isnull().sum()*100,
    'cardinality': df.nunique(),
})
# Out:
#               count  Nulls  nulls%  cardinality
# show_id        8790      0       0         8790
# type           8790      0       0            2
# title          8790      0       0         8787
# director       8790      0       0         4528
# country        8790      0       0           86
# date_added     8790      0       0         1713
# release_year   8790      0       0           74
# rating         8790      0       0           14
# duration       8790      0       0          220
# listed_in      8790      0       0          513

# %% [markdown]
# <div style="background-color: #0f0f0f; padding: 20px; border-radius: 10px; box-shadow: 5px 5px 10px #888888;">
# <h1 style="color: white; font-size: 30px; font-weight: bold; text-align: center; text-shadow: 2px 2px 4px #000000;">Delete unnecessary columns</h1>
# </div>

# %%
df.drop(columns=['show_id'],inplace=True)

# %%
df.sample(5)
# Out:
#        type                            title         director        country  \
# 4092  Movie                            Mercy   Chris Sparling  United States
# 5194  Movie                      John Carter   Andrew Stanton  United States
# 687   Movie  The Guide to the Perfect Family    Ricardo Trogi      Not Given
# 417   Movie                      Tango Feroz  Marcelo Piñeyro      Argentina
# 4091  Movie              Michael Che Matters     Oz Rodriguez  United States
#
#       date_added  release_year rating duration  \
# 4092  11/22/2016          2016  TV-MA   88 min
# 5194    5/2/2019          2012  PG-13  133 min
# 687    7/14/2021          2021  TV-MA  102 min
# 417     8/5/2021          1993  TV-MA  124 min
# 4091  11/25/2016          2016  TV-MA   61 min
#
#                                          listed_in
# 4092                             Dramas, Thrillers
# 5194          Action & Adventure, Sci-Fi & Fantasy
# 687         Comedies, Dramas, International Movies
# ...

# %%
# Shape of DataSet After Delete unnecessary columns
print(f"Number of column :{df.shape[1]}\nNumber of rows :{df.shape[0]}")
# Out:
# Number of column :9
# Number of rows :8790

# %%
df.describe(exclude=np.number)
# Out:
#          type  title   director        country date_added rating  duration  \
# count    8790   8790       8790           8790       8790   8790      8790
# unique      2   8787       4528             86       1713     14       220
# top     Movie  9-Feb  Not Given  United States   1/1/2020  TV-MA  1 Season
# freq     6126      2       2588           3240        110   3205      1791
#
#                            listed_in
# count                           8790
# unique                           513
# top     Dramas, International Movies
# freq                             362

# %% [markdown]
# <div style="background-color: #0f0f0f; padding: 20px; border-radius: 10px; box-shadow: 5px 5px 10px #888888;">
# <h1 style="color: white; font-size: 30px; font-weight: bold; text-align: center; text-shadow: 2px 2px 4px #000000;">Compare Between Two Types</h1>
# </div>

# %%
count_types=df['type'].value_counts()
count_types
# Out:
# Movie      6126
# TV Show    2664
# Name: type, dtype: int64

# %%
iplot(px.bar(count_types,
             text_auto=True,
             color = count_types.index,
             color_discrete_sequence = colors,
             title='Compare Between Two Types',
             labels=dict(index="count_types",value="count")
))
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
iplot(px.pie(values=count_types,
             names=['Movie','TV Show'],
             color_discrete_sequence = colors[7:9],
             title="Ram counts").update_traces(textinfo='value+percent'))
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# <div style="background-color: #0f0f0f; padding: 20px; border-radius: 10px; box-shadow: 5px 5px 10px #888888;">
# <h1 style="color: white; font-size: 30px; font-weight: bold; text-align: center; text-shadow: 2px 2px 4px #000000;">Directors</h1>
# </div>

# %%
directors = df['director'].value_counts()
directors
# Out:
# Not Given                         2588
# Rajiv Chilaka                       20
# Alastair Fothergill                 18
# Raúl Campos, Jan Suter              18
# Suhas Kadav                         16
#                                   ...
# Matt D'Avella                        1
# Parthiban                            1
# Scott McAboy                         1
# Raymie Muzquiz, Stu Livingston       1
# Mozez Singh                          1
# Name: director, Length: 4528, dtype: int64

# %%
given_directors = directors.sum() - directors[0]
print(f'given directors = {given_directors}')
# Out:
# given directors = 6202

# %%
iplot(px.pie(values=[directors[0], given_directors],
             names=['Given Directors', 'Not Given Directors'],
             title='Given Directors Vs Not Given Directors',
             color_discrete_sequence=['#B81D24', '#221F1F']
            ).update_traces(textinfo='value+percent'))
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # top 10 Mentioned Directors

# %%
px.bar(directors[1:11],
      x=directors[1:11],
      y=directors[1:11].index,
      color = directors[1:11].index,
      color_discrete_sequence = colors,
      text_auto = True,
      labels = dict(x='Number of movies', y='Directors'),
      orientation= 'h'
      )
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# <div style="background-color: #0f0f0f; padding: 20px; border-radius: 10px; box-shadow: 5px 5px 10px #888888;">
# <h1 style="color: white; font-size: 30px; font-weight: bold; text-align: center; text-shadow: 2px 2px 4px #000000;">country</h1>
# </div>

# %%
countries = df['country'].value_counts()[:10]
countries
# Out:
# United States     3240
# India             1057
# United Kingdom     638
# Pakistan           421
# Not Given          287
# Canada             271
# Japan              259
# South Korea        214
# France             213
# Spain              182
# Name: country, dtype: int64

# %% [markdown]
# # There's a Relation between country column and type column

# %%
country_type = df.groupby(['country', 'type']).size().unstack(fill_value=0).reset_index()

country_type['Total'] = country_type['Movie'] + country_type['TV Show']

country_type = country_type[country_type['country'] != 'Not Given']

country_type = country_type.sort_values(by='Total', ascending=False)

colors = ['#B81D24', '#221F1F']

fig = px.bar(country_type.head(10), x='country', y=['Movie', 'TV Show'],
             labels={'value': 'Count', 'variable': 'Type'},
             title='Top 10 Countries and their Streamed Movies and TV Shows',
             barmode='group',  # This stacks the bars next to each other
             color_discrete_map={key: value for key, value in zip(['Movie', 'TV Show'], colors)})

fig.update_traces(marker=dict(line=dict(width=4)))

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# <div style="background-color: #0f0f0f; padding: 20px; border-radius: 10px; box-shadow: 5px 5px 10px #888888;">
# <h1 style="color: white; font-size: 30px; font-weight: bold; text-align: center; text-shadow: 2px 2px 4px #000000;">Date_Added</h1>
# </div>

# %%
df['date_added']=pd.to_datetime(df["date_added"])
df['date_added'].head(10)
# Out:
# 0   2021-09-25
# 1   2021-09-24
# 2   2021-09-24
# 3   2021-09-22
# 4   2021-09-24
# 5   2021-09-24
# 6   2021-09-24
# 7   2021-05-01
# 8   2021-09-23
# 9   2021-05-01
# Name: date_added, dtype: datetime64[ns]

# %%
print(df['date_added'].min())
print(df['date_added'].max())
# Out:
# 2008-01-01 00:00:00
# 2021-09-25 00:00:00

# %% [markdown]
# <div style="background-color: #0f0f0f; padding: 20px; border-radius: 10px; box-shadow: 5px 5px 10px #888888;">
# <h1 style="color: white; font-size: 30px; font-weight: bold; text-align: center; text-shadow: 2px 2px 4px #000000;">Release_Year</h1>
# </div>

# %%
release_year = df['release_year'].value_counts()
release_year.head(10)
# Out:
# 2018    1146
# 2017    1030
# 2019    1030
# 2020     953
# 2016     901
# 2021     592
# 2015     555
# 2014     352
# 2013     286
# 2012     236
# Name: release_year, dtype: int64

# %%
iplot(px.area(release_year,
             x=release_year.index,
             y=release_year))
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Movies and TV Shows Added per year

# %%
shows_added_per_year = df.groupby(df['date_added'].dt.year)['type'].count()
shows_added_per_year
# Out:
# date_added
# 2008       2
# 2009       2
# 2010       1
# 2011      13
# 2012       3
# 2013      11
# 2014      24
# 2015      82
# 2016     426
# 2017    1185
# 2018    1648
# 2019    2016
# 2020    1879
# 2021    1498
# Name: type, dtype: int64

# %%
iplot(px.line(shows_added_per_year,
    title='Number Of Shows Added per year',
    x = shows_added_per_year.index,
    y = shows_added_per_year,
    markers = True , line_shape='linear'
))
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# <div style="background-color: #0f0f0f; padding: 20px; border-radius: 10px; box-shadow: 5px 5px 10px #888888;">
# <h1 style="color: white; font-size: 30px; font-weight: bold; text-align: center; text-shadow: 2px 2px 4px #000000;">Rating</h1>
# </div>

# %%
rating = df['rating'].value_counts()
rating.head(10)
# Out:
# TV-MA    3205
# TV-14    2157
# TV-PG     861
# R         799
# PG-13     490
# TV-Y7     333
# TV-Y      306
# PG        287
# TV-G      220
# NR         79
# Name: rating, dtype: int64

# %%
iplot(px.bar(rating,
    title="Shows Rating On Netflix",
    color = rating.index,
    orientation = 'h',
    height = 720,
    text_auto=True,
    labels =dict(index='Rating',value='Frequency'),
))
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# <div style="background-color: #0f0f0f; padding: 20px; border-radius: 10px; box-shadow: 5px 5px 10px #888888;">
# <h1 style="color: white; font-size: 30px; font-weight: bold; text-align: center; text-shadow: 2px 2px 4px #000000;">Duration</h1>
# </div>

# %%
duration =df['duration'].value_counts()
duration.head(10)
# Out:
# 1 Season     1791
# 2 Seasons     421
# 3 Seasons     198
# 90 min        152
# 97 min        146
# 93 min        146
# 94 min        146
# 91 min        144
# 95 min        137
# 96 min        130
# Name: duration, dtype: int64

# %%
seasons = df[df['duration'].str.contains('Season')]
seasons_count = seasons['duration'].value_counts()
seasons_count
# Out:
# 1 Season      1791
# 2 Seasons      421
# 3 Seasons      198
# 4 Seasons       94
# 5 Seasons       64
# 6 Seasons       33
# 7 Seasons       23
# 8 Seasons       17
# 9 Seasons        9
# 10 Seasons       6
# 15 Seasons       2
# 13 Seasons       2
# 12 Seasons       2
# 17 Seasons       1
# 11 Seasons       1
# Name: duration, dtype: int64

# %%
iplot(px.bar(seasons_count,
    title="Season per TV Show",
    color = seasons_count.index,
    orientation = 'h',
    height = 720,
    text_auto=True,
    labels =dict(index='Seasons',value='Sum'),
))
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# <div style="background-color: #0f0f0f; padding: 20px; border-radius: 10px; box-shadow: 5px 5px 10px #888888;">
# <h1 style="color: white; font-size: 30px; font-weight: bold; text-align: center; text-shadow: 2px 2px 4px #000000;">Listed_In</h1>
# </div>

# %%
categories = df['listed_in'].str.split(', ', expand=True)

categories = categories.melt(value_name='category').dropna()['category']

top_categories = categories.value_counts().head(10)

top_categories
# Out:
# International Movies        2752
# Dramas                      2426
# Comedies                    1674
# International TV Shows      1349
# Documentaries                869
# Action & Adventure           859
# TV Dramas                    762
# Independent Movies           756
# Children & Family Movies     641
# Romantic Movies              616
# Name: category, dtype: int64

# %%
top_categories_df = pd.DataFrame({'Category': top_categories.index, 'Count': top_categories.values})

fig = px.bar(top_categories_df, x='Count', y='Category', orientation='h',
             title='Top 10 Popular Categories for Movies & TV Shows',
             labels={'Count': 'Number of Shows', 'Category': 'Category'},
             color=top_categories_df.index,
             text='Count')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
